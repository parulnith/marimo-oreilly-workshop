# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-3, 4, 200)
y = x**5

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("y = x^3")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')
