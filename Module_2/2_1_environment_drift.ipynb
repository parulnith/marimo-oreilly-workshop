# %% [markdown]
# # The "It Works on My Machine" Problem
#
# This notebook demonstrates **environmental drift** when the same code produces different results because the environment changed.
#
# Use it by running the same notebook in two different environments manually and comparing the results.

# %% [markdown]
# ## Example 1: scikit-learn 1.8 feature change
#
# This example uses a feature that exists in scikit-learn 1.8 but not in 1.7.2: `method="temperature"` in `CalibratedClassifierCV`.
#
# Run the cell below in one environment, note what happens, then run the same cell again in the other environment and compare the result.
#
# - In scikit-learn 1.8.0, it should run.
# - In scikit-learn 1.7.2, it should fail because `temperature` calibration is not available.

# %%
import sklearn
from sklearn.calibration import CalibratedClassifierCV
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

print(f"sklearn version: {sklearn.__version__}")

X, y = make_classification(n_samples=300, n_features=10, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

base_model = LogisticRegression(max_iter=1000)
model = CalibratedClassifierCV(base_model, method="temperature", cv=3)
model.fit(X_train, y_train)
accuracy = model.score(X_test, y_test)

print(f"accuracy: {accuracy:.3f}")
# Out:
# sklearn version: 1.7.2
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[1], line 14
#      12 base_model = LogisticRegression(max_iter=1000)
#      13 model = CalibratedClassifierCV(base_model, method="temperature", cv=3)
# ---> 14 model.fit(X_train, y_train)
#      15 accuracy = model.score(X_test, y_test)
#      17 print(f"accuracy: {accuracy:.3f}")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:1358, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1353 partial_fit_and_fitted = (
#    1354     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1355 )
#    1357 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
# ...

# %% [markdown]
# ## Example 2: Pandas API change
#
# This example uses `delim_whitespace=True`, which works in pandas 2.x with a deprecation warning but raises an error in pandas 3.x.
#
# Run the same cell below in two different environments and compare the result.

# %%
from io import StringIO
import pandas as pd

print(f"pandas version: {pd.__version__}")

csv_data = """feature_a feature_b label\n1 10 0\n2 20 1\n3 30 0\n"""
df = pd.read_csv(StringIO(csv_data), delim_whitespace=True)
print(df)
# Out:
# pandas version: 3.0.2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 print(f"pandas version: {pd.__version__}")
#       6 csv_data = """feature_a feature_b label\n1 10 0\n2 20 1\n3 30 0\n"""
# ----> 7 df = pd.read_csv(StringIO(csv_data), delim_whitespace=True)
#       8 print(df)
#
# TypeError: read_csv() got an unexpected keyword argument 'delim_whitespace'
